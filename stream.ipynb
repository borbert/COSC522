# %%
import pyaudio
import wave
import time

chunk = 1024  # Record in chunks of 1024 samples
sample_format = pyaudio.paInt16  # 16 bits per sample
#channels = 2
channels = 1
fs = 44100  # Record at 44100 samples per second
seconds = 30
filename = "output"
typeoFile = ".wav"
index = 0

for i in range(int(21)):
    p = pyaudio.PyAudio()  # Create an interface to PortAudio
    time.sleep(5)
    print('Recording', i) 
    

    stream = p.open(format=sample_format,
                    channels=channels,
                    rate=fs,
                    frames_per_buffer=chunk,
                    input=True)

    frames = []  # Initialize array to store frames

    # Store data in chunks for 3 seconds
    for i in range(0, int(fs / chunk * seconds)):
        data = stream.read(chunk)
        frames.append(data)
        
    

    # Stop and close the stream 
    stream.stop_stream()
    stream.close()
    # Terminate the PortAudio interface
    p.terminate()
    

    print('Finished recording')
    #time.sleep(1)

    # Save the recorded data as a WAV file    
    fullfilename = filename+"_"+str(index)+typeoFile
    print(fullfilename)
    wf = wave.open(fullfilename, 'wb')
    wf.setnchannels(channels)
    wf.setsampwidth(p.get_sample_size(sample_format))
    wf.setframerate(fs)
    wf.writeframes(b''.join(frames))
    wf.close()
    time.sleep(5)
    index +=1
# Out:
# Recording 0
# Finished recording
# output_0.wav
# Recording 1
# Finished recording
# output_1.wav
# Recording 2
# Finished recording
# output_2.wav
# Recording 3
# Finished recording
# output_3.wav
# Recording 4
# Finished recording
# output_4.wav
# Recording 5
# Finished recording
# output_5.wav
# Recording 6
# Finished recording
# output_6.wav
# Recording 7
# Finished recording
# output_7.wav
# Recording 8
# Finished recording
# output_8.wav
# Recording 9
# Finished recording
# output_9.wav
# Recording 10
# Finished recording
# output_10.wav
# Recording 11
# Finished recording
# output_11.wav
# Recording 12
# Finished recording
# output_12.wav
# Recording 13
# Finished recording
# output_13.wav
# Recording 14
# Finished recording
# output_14.wav
# Recording 15
# Finished recording
# output_15.wav
# Recording 16
# Finished recording
# output_16.wav
# Recording 17
# Finished recording
# output_17.wav
# Recording 18
# Finished recording
# output_18.wav
# Recording 19
# Finished recording
# output_19.wav
# Recording 20
# Finished recording
# output_20.wav
